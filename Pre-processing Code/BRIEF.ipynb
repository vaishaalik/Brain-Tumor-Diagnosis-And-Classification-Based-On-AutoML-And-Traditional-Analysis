# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# BREIF

# %%
import numpy as np
import cv2 as cv2
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/drive/MyDrive/BrainTumor/OriginalImages/Training/glioma_tumor/gg (1).jpg',0)
# Initiate FAST detector
star = cv2.xfeatures2d.StarDetector_create()
# Initiate BRIEF extractor
brief = cv2.xfeatures2d.BriefDescriptorExtractor_create()
# find the keypoints with STAR
kp = star.detect(img,None)

#drawing the key points
kp_image = cv2.drawKeypoints(img, kp, None, color=(0, 255, 0), flags=0)
cv2_imshow(kp_image)

# compute the descriptors with BRIEF
kp, des = brief.compute(img, kp)
print( brief.descriptorSize() )
print( des.shape )
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F30F0EEB210>
# 32
# (59, 32)

# %%
import numpy as np
import cv2 as cv2
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/drive/MyDrive/BrainTumor/HSV/Training/glioma_tumor/gg (1).jpg',0)
# Initiate FAST detector
star = cv2.xfeatures2d.StarDetector_create()
# Initiate BRIEF extractor
brief = cv2.xfeatures2d.BriefDescriptorExtractor_create()
# find the keypoints with STAR
kp = star.detect(img,None)

#drawing the key points
kp_image = cv2.drawKeypoints(img, kp, None, color=(0, 255, 0), flags=0)
cv2_imshow(kp_image)

# compute the descriptors with BRIEF
kp, des = brief.compute(img, kp)
print( brief.descriptorSize() )
print( des.shape )
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F30E18BF7D0>
# 32
# (57, 32)

# %%
import numpy as np
import cv2 as cv2
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/drive/MyDrive/BrainTumor/DWTImages/training/glioma_tumor/gg (1)_output.jpg',0)
# Initiate FAST detector
star = cv2.xfeatures2d.StarDetector_create()
# Initiate BRIEF extractor
brief = cv2.xfeatures2d.BriefDescriptorExtractor_create()
# find the keypoints with STAR
kp = star.detect(img,None)

#drawing the key points
kp_image = cv2.drawKeypoints(img, kp, None, color=(0, 255, 0), flags=0)
cv2_imshow(kp_image)

# compute the descriptors with BRIEF
kp, des = brief.compute(img, kp)
print( brief.descriptorSize() )
print( des.shape )
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F5DC89D4210>
# 32
# (169, 32)
